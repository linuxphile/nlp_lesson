# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
SENT_DETECTOR = nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# ## SPACY POS Tags
#
# TEXT	LEMMA	POS	    TAG	    DEP	        SHAPE	ALPHA	STOP
# Apple	apple	PROPN	NNP	    nsubj	    Xxxxx	True	False
# is	    be	    AUX	    VBZ	    aux	        xx	    True	True
# looking	look	VERB	VBG	    ROOT	    xxxx	True	False
# at	    at	    ADP	    IN	    prep        xx	    True	True
# buying	buy	    VERB	VBG	    pcomp	    xxxx	True	False
# U.K.	u.k.	PROPN	NNP	    compound	X.X.	False	False
# startup	startup	NOUN	NN	    dobj	    xxxx	True	False
# for	    for	    ADP	    IN	    prep	    xxx	    True	True
# $	    $	    SYM	    $	    quantmod	$	    False	False
# 1	    1	    NUM	    CD	    compound	d	    False	False
# billion	billion	NUM	    CD	    pobj	    xxxx	True	False

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
introduction_text = ("Professor McCarthy is my favorite teacher....I really enjoy his lectures. He is an expert in artificial intelligence.")
introduction_doc = nlp(introduction_text)
# Extract tokens for the given doc
print ([token.text for token in introduction_doc])
# Out:
# ['Professor', 'McCarthy', 'is', 'my', 'favorite', 'teacher', '....', 'I', 'really', 'enjoy', 'his', 'lectures', '.', 'He', 'is', 'an', 'expert', 'in', 'artificial', 'intelligence', '.']

# %%
#More often we work with text in files 
file_name = "introduction.txt"
introduction_file = open(file_name).read()
introduction_file_doc = nlp(introduction_file)
print ([token.text for token in introduction_file_doc])
# Out:
# ['We', 'will', 'learn', 'about', 'processing', 'language', 'using', 'spacy', '.', '\n', 'We', 'will', 'learn', 'about', 'sentences', '.', '\n', 'We', 'will', 'learn', 'about', 'tokens', '.', '\n', 'We', 'will', 'learn', 'about', 'people', ',', 'like', 'Professor', 'Daniel', 'McCarthy', '.', '\n', 'We', 'will', 'learn', 'about', 'places', ',', 'like', 'Washington', 'D.C.', '\n', 'We', 'will', 'learning', 'about', 'proper', 'nouns', 'like', 'Strayer', 'University', '.', '\n', 'We', 'will', 'learn', 'about', 'pre', '-', 'processing', 'and', 'the', 'removal', 'of', 'stop', '-', 'words', '.', '\n', 'We', 'will', 'learn', 'about', 'lemmatization', '.', '\n', 'We', 'will', 'learn', 'about', 'parts', 'of', 'speech', '.', '\n', 'Mr.', 'McCarthy', 'likes', 'diet', 'Dr.', 'Pepper', '.', '\n']

# %%
#Extracting stop words and punctuations from the text
from collections import Counter
words = [ token.text for token in introduction_file_doc if not token.is_stop and not token.is_punct]
print(Counter(words).most_common(5))
# Out:
# [('learning', 1), ('pre', 1), ('processing', 1), ('lemmatization', 1), ('\n', 1)]

# %%
#
for token in introduction_file_doc:
    print (token, token.lemma_)
# Out:
# We we
# will will
# be be
# learning learn
# about about
# pre pre
# - -
# processing processing
# and and
# lemmatization lemmatization
# . .
#
#
#
# The the
# meaning meaning
# of of
# supposition supposition
# is be
# a a
# thing thing
# tacitly tacitly
# assumed assume
# beforehand beforehand
# . .

# %%
#part of speech tagging
for token in introduction_file_doc:
    if not token.is_stop and not token.is_punct:
        print (token, token.pos_)
# Out:
# learning VERB
# pre ADJ
# processing NOUN
# lemmatization NOUN
#
#  SPACE
# meaning NOUN
# supposition NOUN
# thing NOUN
# tacitly ADV
# assumed VERB

# %%
#Named entity recognition
for ent in introduction_file_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Daniel McCarthy PERSON
# Washington D.C. GPE
# Strayer University ORG
# McCarthy PERSON
# Pepper PERSON

# %%
#displaying the named entities in the text
from spacy import displacy
displacy.render(introduction_file_doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">We will learn about processing language using spacy. <br>We will learn about sentences. <br>We will learn about tokens. <br>We will learn about people, like Professor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daniel McCarthy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . <br>We will learn about places, like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington D.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>We will learning about proper nouns like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strayer University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . <br>We will learn about pre-processing and the removal of stop-words. <br>We will learn about lemmatization. <br>We will learn about parts of speech. <br>Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCarthy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  likes diet Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . <br></div></span>

# %%
introduction_text = "This tutorial is about Natural Language Processing in Spacy."
introduction_doc = nlp(introduction_text)
displacy.serve(introduction_doc, style="dep")
# Out:
# /home/dmccarthy/anaconda3/envs/autochain/lib/python3.10/site-packages/spacy/displacy/__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2eeb8fb8bc6d41eca6ee4939bf9e8c35-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">tutorial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Spacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-5" stroke-width="2px" d="M595,177.0 C595,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-6" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,179.0 L1278.0,167.0 1262.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-7" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2eeb8fb8bc6d41eca6ee4939bf9e8c35-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,179.0 L1453.0,167.0 1437.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
about_text = """According to the outlet, the OpenAI CEO recently reached an agreement with the iPhone maker to incorporate some OpenAI services into Apple products. Nadella was reportedly concerned about the potential impact of a deal on Microsoft's product ambitions, per the report.

Representatives for OpenAI, Apple, and Microsoft did not immediately respond to requests for comment from Business Insider, made outside normal working hours. Apple and OpenAI declined to comment to The Information.
If OpenAI has indeed reached an agreement with Apple, it would be a much-needed win for Altman.
The tech boss has faced heightened scrutiny after former employees and board members publicly criticized him.
Helen Toner, a former OpenAI director, recently accused Altman of lying to the board "multiple" times and "withholding information.
Toner, who participated in November's ousting of the CEO, said Altman had also kept the board in the dark about the company's ownership structure.

Altman has also faced criticism from Jan Lieke, a former executive at OpenAI.

Leike quit OpenAI earlier this month, accusing the company of prioritizing "shiny products" over "safety culture and processes."

Tensions over the priorities within OpenAI had reportedly been brewing since Altman's brief ouster.

"""

about_doc = nlp(about_text)
sentences = list(about_doc.sents)
num_sentences = len(sentences)
print("sentences: " + str(num_sentences))
for sentence in sentences:
    print(sentence)
# Out:
# sentences: 10
# According to the outlet, the OpenAI CEO recently reached an agreement with the iPhone maker to incorporate some OpenAI services into Apple products.
# Nadella was reportedly concerned about the potential impact of a deal on Microsoft's product ambitions, per the report.
#
#
# Representatives for OpenAI, Apple, and Microsoft did not immediately respond to requests for comment from Business Insider, made outside normal working hours.
# Apple and OpenAI declined to comment to The Information.
#
# If OpenAI has indeed reached an agreement with Apple, it would be a much-needed win for Altman.
#
# The tech boss has faced heightened scrutiny after former employees and board members publicly criticized him.
#
# Helen Toner, a former OpenAI director, recently accused Altman of lying to the board "multiple" times and "withholding information.
# Toner, who participated in November's ousting of the CEO, said Altman had also kept the board in the dark about the company's ownership structure.
#
#
# Altman has also faced criticism from Jan Lieke, a former executive at OpenAI.
#
#
# Leike quit OpenAI earlier this month, accusing the company of prioritizing "shiny products" over "safety culture and processes.
# "
#
# Tensions over the priorities within OpenAI had reportedly been brewing since Altman's brief ouster.

# %%
#tokens
for token in about_doc:
    print (token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# According accord VERB VBG prep Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# outlet outlet NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# OpenAI OpenAI PROPN NNP compound XxxxXX True False
# CEO CEO PROPN NNP nsubj XXX True False
# recently recently ADV RB advmod xxxx True False
# reached reach VERB VBD ROOT xxxx True False
# an an DET DT det xx True True
# agreement agreement NOUN NN dobj xxxx True False
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# iPhone iPhone PROPN NNP compound xXxxxx True False
# maker maker NOUN NN pobj xxxx True False
# to to PART TO aux xx True True
# incorporate incorporate VERB VB acl xxxx True False
# some some DET DT det xxxx True True
# OpenAI OpenAI PROPN NNP compound XxxxXX True False
# services service NOUN NNS dobj xxxx True False
# into into ADP IN prep xxxx True True
# Apple Apple PROPN NNP compound Xxxxx True False
# products product NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Nadella Nadella PROPN NNP nsubj Xxxxx True False
# was be AUX VBD ROOT xxx True True
# reportedly reportedly ADV RB advmod xxxx True False
# concerned concerned ADJ JJ acomp xxxx True False
# about about ADP IN prep xxxx True True
# the the DET DT det xxx True True
# potential potential ADJ JJ amod xxxx True False
# impact impact NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# deal deal NOUN NN pobj xxxx True False
# on on ADP IN prep xx True True
# Microsoft Microsoft PROPN NNP poss Xxxxx True False
# 's 's PART POS case 'x False True
# product product NOUN NN compound xxxx True False
# ambitions ambition NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# per per ADP IN prep xxx True True
# the the DET DT det xxx True True
# report report NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP dep
#
#  False False
# Representatives Representatives PROPN NNP nsubj Xxxxx True False
# for for ADP IN prep xxx True True
# OpenAI OpenAI PROPN NNP pobj XxxxXX True False
# , , PUNCT , punct , False False
# Apple Apple PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# Microsoft Microsoft PROPN NNP conj Xxxxx True False
# did do AUX VBD aux xxx True True
# not not PART RB neg xxx True True
# immediately immediately ADV RB advmod xxxx True False
# respond respond VERB VB ROOT xxxx True False
# to to ADP IN prep xx True True
# requests request NOUN NNS pobj xxxx True False
# for for ADP IN prep xxx True True
# comment comment NOUN NN pobj xxxx True False
# from from ADP IN prep xxxx True True
# Business Business PROPN NNP compound Xxxxx True False
# Insider Insider PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# made make VERB VBD advcl xxxx True True
# outside outside ADP IN prep xxxx True False
# normal normal ADJ JJ amod xxxx True False
# working working NOUN NN compound xxxx True False
# hours hour NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Apple Apple PROPN NNP nsubj Xxxxx True False
# and and CCONJ CC cc xxx True True
# OpenAI OpenAI PROPN NNP conj XxxxXX True False
# declined decline VERB VBD ROOT xxxx True False
# to to PART TO aux xx True True
# comment comment VERB VB xcomp xxxx True False
# to to ADP IN prep xx True True
# The the DET DT det Xxx True True
# Information Information PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP dep
#  False False
# If if SCONJ IN mark Xx True True
# OpenAI OpenAI PROPN NNP nsubj XxxxXX True False
# has have AUX VBZ aux xxx True True
# indeed indeed ADV RB advmod xxxx True True
# reached reach VERB VBN advcl xxxx True False
# an an DET DT det xx True True
# agreement agreement NOUN NN dobj xxxx True False
# with with ADP IN prep xxxx True True
# Apple Apple PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# it it PRON PRP nsubj xx True True
# would would AUX MD aux xxxx True True
# be be AUX VB ROOT xx True True
# a a DET DT det x True True
# much much ADV RB advmod xxxx True True
# - - PUNCT HYPH punct - False False
# needed need VERB VBN amod xxxx True False
# win win NOUN NN attr xxx True False
# for for ADP IN prep xxx True True
# Altman Altman PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP dep
#  False False
# The the DET DT det Xxx True True
# tech tech NOUN NN compound xxxx True False
# boss boss NOUN NN nsubj xxxx True False
# has have AUX VBZ aux xxx True True
# faced face VERB VBN ROOT xxxx True False
# heightened heighten VERB VBN amod xxxx True False
# scrutiny scrutiny NOUN NN dobj xxxx True False
# after after SCONJ IN mark xxxx True True
# former former ADJ JJ amod xxxx True True
# employees employee NOUN NNS nsubj xxxx True False
# and and CCONJ CC cc xxx True True
# board board NOUN NN compound xxxx True False
# members member NOUN NNS conj xxxx True False
# publicly publicly ADV RB advmod xxxx True False
# criticized criticize VERB VBD advcl xxxx True False
# him he PRON PRP dobj xxx True True
# . . PUNCT . punct . False False
#
#
#  SPACE _SP dep
#  False False
# Helen Helen PROPN NNP compound Xxxxx True False
# Toner Toner PROPN NNP nsubj Xxxxx True False
# , , PUNCT , punct , False False
# a a DET DT det x True True
# former former ADJ JJ amod xxxx True True
# OpenAI OpenAI PROPN NNP compound XxxxXX True False
# director director NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# recently recently ADV RB advmod xxxx True False
# accused accuse VERB VBD ccomp xxxx True False
# Altman Altman PROPN NNP dobj Xxxxx True False
# of of ADP IN prep xx True True
# lying lie VERB VBG pcomp xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# board board NOUN NN nmod xxxx True False
# " " PUNCT `` punct " False False
# multiple multiple ADJ JJ amod xxxx True False
# " " PUNCT '' punct " False False
# times time NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True True
# " " PUNCT `` punct " False False
# withholding withhold VERB VBG amod xxxx True False
# information information NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP dep
#  False False
# Toner Toner PROPN NNP dobj Xxxxx True False
# , , PUNCT , punct , False False
# who who PRON WP nsubj xxx True True
# participated participate VERB VBD relcl xxxx True False
# in in ADP IN prep xx True True
# November November PROPN NNP poss Xxxxx True False
# 's 's PART POS case 'x False True
# ousting ousting NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# CEO CEO PROPN NNP pobj XXX True False
# , , PUNCT , punct , False False
# said say VERB VBD ROOT xxxx True False
# Altman Altman PROPN NNP nsubj Xxxxx True False
# had have AUX VBD aux xxx True True
# also also ADV RB advmod xxxx True True
# kept keep VERB VBN ccomp xxxx True False
# the the DET DT det xxx True True
# board board NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# dark dark NOUN NN pobj xxxx True False
# about about ADP IN prep xxxx True True
# the the DET DT det xxx True True
# company company NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# ownership ownership NOUN NN compound xxxx True False
# structure structure NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP dep
#
#  False False
# Altman Altman PROPN NNP nsubj Xxxxx True False
# has have AUX VBZ aux xxx True True
# also also ADV RB advmod xxxx True True
# faced face VERB VBN ROOT xxxx True False
# criticism criticism NOUN NN dobj xxxx True False
# from from ADP IN prep xxxx True True
# Jan Jan PROPN NNP compound Xxx True False
# Lieke Lieke PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# a a DET DT det x True True
# former former ADJ JJ amod xxxx True True
# executive executive NOUN NN appos xxxx True False
# at at ADP IN prep xx True True
# OpenAI OpenAI PROPN NNP pobj XxxxXX True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP dep
#
#  False False
# Leike Leike PROPN NNP nsubj Xxxxx True False
# quit quit VERB VBD ROOT xxxx True False
# OpenAI OpenAI PROPN NNP dobj XxxxXX True False
# earlier early ADV RBR advmod xxxx True False
# this this DET DT det xxxx True True
# month month NOUN NN npadvmod xxxx True False
# , , PUNCT , punct , False False
# accusing accuse VERB VBG advcl xxxx True False
# the the DET DT det xxx True True
# company company NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# prioritizing prioritize VERB VBG pcomp xxxx True False
# " " PUNCT `` punct " False False
# shiny shiny ADJ JJ amod xxxx True False
# products product NOUN NNS dobj xxxx True False
# " " PUNCT '' punct " False False
# over over ADP IN prep xxxx True True
# " " PUNCT `` punct " False False
# safety safety NOUN NN compound xxxx True False
# culture culture NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# processes process NOUN NNS conj xxxx True False
# . . PUNCT . punct . False False
# " " PUNCT `` punct " False False
#
#
#
#
#  SPACE _SP dep
#
#  False False
# Tensions tension NOUN NNS nsubj Xxxxx True False
# over over ADP IN prep xxxx True True
# the the DET DT det xxx True True
# priorities priority NOUN NNS pobj xxxx True False
# within within ADP IN prep xxxx True True
# OpenAI OpenAI PROPN NNP pobj XxxxXX True False
# had have AUX VBD aux xxx True True
# reportedly reportedly ADV RB advmod xxxx True False
# been be AUX VBN aux xxxx True True
# brewing brew VERB VBG ROOT xxxx True False
# since since SCONJ IN prep xxxx True True
# Altman Altman PROPN NNP poss Xxxxx True False
# 's 's PART POS case 'x False True
# brief brief ADJ JJ amod xxxx True False
# ouster ouster NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP dep
#
#  False False

# %%
for word in about_doc.ents:
    print(word.text, word.label_)
# Out:
# OpenAI GPE
# iPhone ORG
# OpenAI GPE
# Apple ORG
# Nadella PERSON
# Microsoft ORG
# OpenAI GPE
# Apple ORG
# Microsoft ORG
# Business Insider ORG
# normal working hours TIME
# Apple ORG
# OpenAI ORG
# Information ORG
# OpenAI GPE
# Apple ORG
# Altman PRODUCT
# Helen Toner PERSON
# OpenAI GPE
# Altman ORG
# Toner PERSON
# November DATE
# Altman ORG
# Altman ORG
# Jan Lieke PERSON
# OpenAI GPE
# Leike PERSON
# OpenAI GPE
# earlier this month DATE
# OpenAI GPE
# Altman ORG

# %% [markdown]
# ## NLTK POS Meaning
# CC: It is the conjunction of coordinating
# CD: It is a digit of cardinal
# DT: It is the determiner
# EX: Existential
# FW: It is a foreign word
# IN: Preposition and conjunction
# JJ: Adjective
# JJR and JJS: Adjective and superlative
# LS: List marker
# MD: Modal
# NN: Singular noun
# NNS, NNP, NNPS: Proper and plural noun
# PDT: Predeterminer
# WRB: Adverb of wh
# WP$: Possessive wh
# WP: Pronoun of wh
# WDT: Determiner of wp
# VBZ: Verb
# VBP, VBN, VBG, VBD, VB: Forms of verbs
# UH: Interjection
# TO: To go
# RP: Particle
# RBS, RB, RBR: Adverb
# PRP, PRP$: Pronoun personal and professional

# %%
import nltk

def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

about_text = """According to the outlet, the OpenAI CEO recently reached an agreement with the iPhone maker to incorporate some OpenAI services into Apple products. Nadella was reportedly concerned about the potential impact of a deal on Microsoft's product ambitions, per the report.

Representatives for OpenAI, Apple, and Microsoft did not immediately respond to requests for comment from Business Insider, made outside normal working hours. Apple and OpenAI declined to comment to The Information.
If OpenAI has indeed reached an agreement with Apple, it would be a much-needed win for Altman.
The tech boss has faced heightened scrutiny after former employees and board members publicly criticized him.
Helen Toner, a former OpenAI director, recently accused Altman of lying to the board "multiple" times and "withholding information.
Toner, who participated in November's ousting of the CEO, said Altman had also kept the board in the dark about the company's ownership structure.

Altman has also faced criticism from Jan Lieke, a former executive at OpenAI.

Leike quit OpenAI earlier this month, accusing the company of prioritizing "shiny products" over "safety culture and processes."

Tensions over the priorities within OpenAI had reportedly been brewing since Altman's brief ouster.

"""

pattern = r"""
    NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
        {<NNP>+}                # chunk sequences of proper nouns
"""

sent = preprocess(about_text)
print(sent)
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# [('According', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('outlet', 'NN'), (',', ','), ('the', 'DT'), ('OpenAI', 'NNP'), ('CEO', 'NNP'), ('recently', 'RB'), ('reached', 'VBD'), ('an', 'DT'), ('agreement', 'NN'), ('with', 'IN'), ('the', 'DT'), ('iPhone', 'NN'), ('maker', 'NN'), ('to', 'TO'), ('incorporate', 'VB'), ('some', 'DT'), ('OpenAI', 'NNP'), ('services', 'NNS'), ('into', 'IN'), ('Apple', 'NNP'), ('products', 'NNS'), ('.', '.'), ('Nadella', 'NN'), ('was', 'VBD'), ('reportedly', 'RB'), ('concerned', 'VBN'), ('about', 'IN'), ('the', 'DT'), ('potential', 'JJ'), ('impact', 'NN'), ('of', 'IN'), ('a', 'DT'), ('deal', 'NN'), ('on', 'IN'), ('Microsoft', 'NNP'), ("'s", 'POS'), ('product', 'NN'), ('ambitions', 'NNS'), (',', ','), ('per', 'IN'), ('the', 'DT'), ('report', 'NN'), ('.', '.'), ('Representatives', 'NNS'), ('for', 'IN'), ('OpenAI', 'NNP'), (',', ','), ('Apple', 'NNP'), (',', ','), ('and', 'CC'), ('Microsoft', 'NNP'), ('did', 'VBD'), ('not', 'RB'), ('immediately', 'RB'), ('respond', 'VB'), ('to', 'TO'), ('requests', 'NNS'), ('for', 'IN'), ('comment', 'NN'), ('from', 'IN'), ('Business', 'NNP'), ('Insider', 'NNP'), (',', ','), ('made', 'VBD'), ('outside', 'IN'), ('normal', 'JJ'), ('working', 'JJ'), ('hours', 'NNS'), ('.', '.'), ('Apple', 'NNP'), ('and', 'CC'), ('OpenAI', 'NNP'), ('declined', 'VBD'), ('to', 'TO'), ('comment', 'VB'), ('to', 'TO'), ('The', 'DT'), ('Information', 'NNP'), ('.', '.'), ('If', 'IN'), ('OpenAI', 'NNP'), ('has', 'VBZ'), ('indeed', 'RB'), ('reached', 'VBN'), ('an', 'DT'), ('agreement', 'NN'), ('with', 'IN'), ('Apple', 'NNP'), (',', ','), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('a', 'DT'), ('much-needed', 'JJ'), ('win', 'NN'), ('for', 'IN'), ('Altman', 'NNP'), ('.', '.'), ('The', 'DT'), ('tech', 'NN'), ('boss', 'NN'), ('has', 'VBZ'), ('faced', 'VBN'), ('heightened', 'VBN'), ('scrutiny', 'NN'), ('after', 'IN'), ('former', 'JJ'), ('employees', 'NNS'), ('and', 'CC'), ('board', 'NN'), ('members', 'NNS'), ('publicly', 'RB'), ('criticized', 'VBD'), ('him', 'PRP'), ('.', '.'), ('Helen', 'NNP'), ('Toner', 'NNP'), (',', ','), ('a', 'DT'), ('former', 'JJ'), ('OpenAI', 'NNP'), ('director', 'NN'), (',', ','), ('recently', 'RB'), ('accused', 'VBD'), ('Altman', 'NNP'), ('of', 'IN'), ('lying', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('board', 'NN'), ('``', '``'), ('multiple', 'NN'), ("''", "''"), ('times', 'NNS'), ('and', 'CC'), ('``', '``'), ('withholding', 'JJ'), ('information', 'NN'), ('.', '.'), ('Toner', 'NNP'), (',', ','), ('who', 'WP'), ('participated', 'VBD'), ('in', 'IN'), ('November', 'NNP'), ("'s", 'POS'), ('ousting', 'NN'), ('of', 'IN'), ('the', 'DT'), ('CEO', 'NNP'), (',', ','), ('said', 'VBD'), ('Altman', 'NNP'), ('had', 'VBD'), ('also', 'RB'), ('kept', 'VBN'), ('the', 'DT'), ('board', 'NN'), ('in', 'IN'), ('the', 'DT'), ('dark', 'NN'), ('about', 'IN'), ('the', 'DT'), ('company', 'NN'), ("'s", 'POS'), ('ownership', 'NN'), ('structure', 'NN'), ('.', '.'), ('Altman', 'NNP'), ('has', 'VBZ'), ('also', 'RB'), ('faced', 'VBN'), ('criticism', 'NN'), ('from', 'IN'), ('Jan', 'NNP'), ('Lieke', 'NNP'), (',', ','), ('a', 'DT'), ('former', 'JJ'), ('executive', 'NN'), ('at', 'IN'), ('OpenAI', 'NNP'), ('.', '.'), ('Leike', 'NNP'), ('quit', 'NN'), ('OpenAI', 'NNP'), ('earlier', 'RBR'), ('this', 'DT'), ('month', 'NN'), (',', ','), ('accusing', 'VBG'), ('the', 'DT'), ('company', 'NN'), ('of', 'IN'), ('prioritizing', 'VBG'), ('``', '``'), ('shiny', 'JJ'), ('products', 'NNS'), ("''", "''"), ('over', 'IN'), ('``', '``'), ('safety', 'NN'), ('culture', 'NN'), ('and', 'CC'), ('processes', 'NNS'), ('.', '.'), ("''", "''"), ('Tensions', 'NNPS'), ('over', 'IN'), ('the', 'DT'), ('priorities', 'NNS'), ('within', 'IN'), ('OpenAI', 'NNP'), ('had', 'VBD'), ('reportedly', 'RB'), ('been', 'VBN'), ('brewing', 'VBG'), ('since', 'IN'), ('Altman', 'NNP'), ("'s", 'POS'), ('brief', 'NN'), ('ouster', 'NN'), ('.', '.')]
# (S
#   According/VBG
#   to/TO
#   (NP the/DT outlet/NN)
#   ,/,
#   the/DT
#   (NP OpenAI/NNP CEO/NNP)
#   recently/RB
#   reached/VBD
#   (NP an/DT agreement/NN)
#   with/IN
#   (NP the/DT iPhone/NN)
#   (NP maker/NN)
#   to/TO
#   incorporate/VB
#   some/DT
#   (NP OpenAI/NNP)
#   services/NNS
#   into/IN
#   (NP Apple/NNP)
#   products/NNS
#   ./.
#   (NP Nadella/NN)
#   was/VBD
#   reportedly/RB
#   concerned/VBN
#   about/IN
#   (NP the/DT potential/JJ impact/NN)
#   of/IN
#   (NP a/DT deal/NN)
#   on/IN
#   (NP Microsoft/NNP)
#   's/POS
#   (NP product/NN)
#   ambitions/NNS
#   ,/,
#   per/IN
#   (NP the/DT report/NN)
#   ./.
#   Representatives/NNS
#   for/IN
#   (NP OpenAI/NNP)
#   ,/,
#   (NP Apple/NNP)
#   ,/,
#   and/CC
#   (NP Microsoft/NNP)
#   did/VBD
#   not/RB
#   immediately/RB
#   respond/VB
#   to/TO
#   requests/NNS
#   for/IN
#   (NP comment/NN)
#   from/IN
#   (NP Business/NNP Insider/NNP)
#   ,/,
#   made/VBD
#   outside/IN
#   normal/JJ
#   working/JJ
#   hours/NNS
#   ./.
#   (NP Apple/NNP)
#   and/CC
#   (NP OpenAI/NNP)
#   declined/VBD
#   to/TO
#   comment/VB
#   to/TO
#   The/DT
#   (NP Information/NNP)
#   ./.
#   If/IN
#   (NP OpenAI/NNP)
#   has/VBZ
#   indeed/RB
#   reached/VBN
#   (NP an/DT agreement/NN)
#   with/IN
#   (NP Apple/NNP)
#   ,/,
#   it/PRP
#   would/MD
#   be/VB
#   (NP a/DT much-needed/JJ win/NN)
#   for/IN
#   (NP Altman/NNP)
#   ./.
#   (NP The/DT tech/NN)
#   (NP boss/NN)
#   has/VBZ
#   faced/VBN
#   heightened/VBN
#   (NP scrutiny/NN)
#   after/IN
#   former/JJ
#   employees/NNS
#   and/CC
#   (NP board/NN)
#   members/NNS
#   publicly/RB
#   criticized/VBD
#   him/PRP
#   ./.
#   (NP Helen/NNP Toner/NNP)
#   ,/,
#   a/DT
#   former/JJ
#   (NP OpenAI/NNP)
#   (NP director/NN)
#   ,/,
#   recently/RB
#   accused/VBD
#   (NP Altman/NNP)
#   of/IN
#   lying/VBG
#   to/TO
#   (NP the/DT board/NN)
#   ``/``
#   (NP multiple/NN)
#   ''/''
#   times/NNS
#   and/CC
#   ``/``
#   (NP withholding/JJ information/NN)
#   ./.
#   (NP Toner/NNP)
#   ,/,
#   who/WP
#   participated/VBD
#   in/IN
#   (NP November/NNP)
#   's/POS
#   (NP ousting/NN)
#   of/IN
#   the/DT
#   (NP CEO/NNP)
#   ,/,
#   said/VBD
#   (NP Altman/NNP)
#   had/VBD
#   also/RB
#   kept/VBN
#   (NP the/DT board/NN)
#   in/IN
#   (NP the/DT dark/NN)
#   about/IN
#   (NP the/DT company/NN)
#   's/POS
#   (NP ownership/NN)
#   (NP structure/NN)
#   ./.
#   (NP Altman/NNP)
#   has/VBZ
#   also/RB
#   faced/VBN
#   (NP criticism/NN)
#   from/IN
#   (NP Jan/NNP Lieke/NNP)
#   ,/,
#   (NP a/DT former/JJ executive/NN)
#   at/IN
#   (NP OpenAI/NNP)
#   ./.
#   (NP Leike/NNP)
#   (NP quit/NN)
#   (NP OpenAI/NNP)
#   earlier/RBR
#   (NP this/DT month/NN)
#   ,/,
#   accusing/VBG
#   (NP the/DT company/NN)
#   of/IN
#   prioritizing/VBG
#   ``/``
#   shiny/JJ
#   products/NNS
#   ''/''
#   over/IN
#   ``/``
#   (NP safety/NN)
#   (NP culture/NN)
#   and/CC
#   processes/NNS
#   ./.
#   ''/''
#   Tensions/NNPS
#   over/IN
#   the/DT
#   priorities/NNS
#   within/IN
#   (NP OpenAI/NNP)
#   had/VBD
#   reportedly/RB
#   been/VBN
#   brewing/VBG
#   since/IN
#   (NP Altman/NNP)
#   's/POS
#   (NP brief/NN)
#   (NP ouster/NN)
#   ./.)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('According', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('outlet', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('CEO', 'NNP', 'I-NP'),
#  ('recently', 'RB', 'O'),
#  ('reached', 'VBD', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('agreement', 'NN', 'I-NP'),
#  ('with', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('iPhone', 'NN', 'I-NP'),
#  ('maker', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('incorporate', 'VB', 'O'),
#  ('some', 'DT', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('services', 'NNS', 'O'),
#  ('into', 'IN', 'O'),
#  ('Apple', 'NNP', 'B-NP'),
#  ('products', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Nadella', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('reportedly', 'RB', 'O'),
#  ('concerned', 'VBN', 'O'),
#  ('about', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('potential', 'JJ', 'I-NP'),
#  ('impact', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('deal', 'NN', 'I-NP'),
#  ('on', 'IN', 'O'),
#  ('Microsoft', 'NNP', 'B-NP'),
#  ("'s", 'POS', 'O'),
#  ('product', 'NN', 'B-NP'),
#  ('ambitions', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('per', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('report', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Representatives', 'NNS', 'O'),
#  ('for', 'IN', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  (',', ',', 'O'),
#  ('Apple', 'NNP', 'B-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('Microsoft', 'NNP', 'B-NP'),
#  ('did', 'VBD', 'O'),
#  ('not', 'RB', 'O'),
#  ('immediately', 'RB', 'O'),
#  ('respond', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('requests', 'NNS', 'O'),
#  ('for', 'IN', 'O'),
#  ('comment', 'NN', 'B-NP'),
#  ('from', 'IN', 'O'),
#  ('Business', 'NNP', 'B-NP'),
#  ('Insider', 'NNP', 'I-NP'),
#  (',', ',', 'O'),
#  ('made', 'VBD', 'O'),
#  ('outside', 'IN', 'O'),
#  ('normal', 'JJ', 'O'),
#  ('working', 'JJ', 'O'),
#  ('hours', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Apple', 'NNP', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('declined', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('comment', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('The', 'DT', 'O'),
#  ('Information', 'NNP', 'B-NP'),
#  ('.', '.', 'O'),
#  ('If', 'IN', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('has', 'VBZ', 'O'),
#  ('indeed', 'RB', 'O'),
#  ('reached', 'VBN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('agreement', 'NN', 'I-NP'),
#  ('with', 'IN', 'O'),
#  ('Apple', 'NNP', 'B-NP'),
#  (',', ',', 'O'),
#  ('it', 'PRP', 'O'),
#  ('would', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('much-needed', 'JJ', 'I-NP'),
#  ('win', 'NN', 'I-NP'),
#  ('for', 'IN', 'O'),
#  ('Altman', 'NNP', 'B-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('tech', 'NN', 'I-NP'),
#  ('boss', 'NN', 'B-NP'),
#  ('has', 'VBZ', 'O'),
#  ('faced', 'VBN', 'O'),
#  ('heightened', 'VBN', 'O'),
#  ('scrutiny', 'NN', 'B-NP'),
#  ('after', 'IN', 'O'),
#  ('former', 'JJ', 'O'),
#  ('employees', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('board', 'NN', 'B-NP'),
#  ('members', 'NNS', 'O'),
#  ('publicly', 'RB', 'O'),
#  ('criticized', 'VBD', 'O'),
#  ('him', 'PRP', 'O'),
#  ('.', '.', 'O'),
#  ('Helen', 'NNP', 'B-NP'),
#  ('Toner', 'NNP', 'I-NP'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'O'),
#  ('former', 'JJ', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('director', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('recently', 'RB', 'O'),
#  ('accused', 'VBD', 'O'),
#  ('Altman', 'NNP', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('lying', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('board', 'NN', 'I-NP'),
#  ('``', '``', 'O'),
#  ('multiple', 'NN', 'B-NP'),
#  ("''", "''", 'O'),
#  ('times', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('``', '``', 'O'),
#  ('withholding', 'JJ', 'B-NP'),
#  ('information', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Toner', 'NNP', 'B-NP'),
#  (',', ',', 'O'),
#  ('who', 'WP', 'O'),
#  ('participated', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('November', 'NNP', 'B-NP'),
#  ("'s", 'POS', 'O'),
#  ('ousting', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('CEO', 'NNP', 'B-NP'),
#  (',', ',', 'O'),
#  ('said', 'VBD', 'O'),
#  ('Altman', 'NNP', 'B-NP'),
#  ('had', 'VBD', 'O'),
#  ('also', 'RB', 'O'),
#  ('kept', 'VBN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('board', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('dark', 'NN', 'I-NP'),
#  ('about', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('company', 'NN', 'I-NP'),
#  ("'s", 'POS', 'O'),
#  ('ownership', 'NN', 'B-NP'),
#  ('structure', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Altman', 'NNP', 'B-NP'),
#  ('has', 'VBZ', 'O'),
#  ('also', 'RB', 'O'),
#  ('faced', 'VBN', 'O'),
#  ('criticism', 'NN', 'B-NP'),
#  ('from', 'IN', 'O'),
#  ('Jan', 'NNP', 'B-NP'),
#  ('Lieke', 'NNP', 'I-NP'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('former', 'JJ', 'I-NP'),
#  ('executive', 'NN', 'I-NP'),
#  ('at', 'IN', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Leike', 'NNP', 'B-NP'),
#  ('quit', 'NN', 'B-NP'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('earlier', 'RBR', 'O'),
#  ('this', 'DT', 'B-NP'),
#  ('month', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('accusing', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('company', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('prioritizing', 'VBG', 'O'),
#  ('``', '``', 'O'),
#  ('shiny', 'JJ', 'O'),
#  ('products', 'NNS', 'O'),
#  ("''", "''", 'O'),
#  ('over', 'IN', 'O'),
#  ('``', '``', 'O'),
#  ('safety', 'NN', 'B-NP'),
#  ('culture', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('processes', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ("''", "''", 'O'),
#  ('Tensions', 'NNPS', 'O'),
#  ('over', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('priorities', 'NNS', 'O'),
#  ('within', 'IN', 'O'),
#  ('OpenAI', 'NNP', 'B-NP'),
#  ('had', 'VBD', 'O'),
#  ('reportedly', 'RB', 'O'),
#  ('been', 'VBN', 'O'),
#  ('brewing', 'VBG', 'O'),
#  ('since', 'IN', 'O'),
#  ('Altman', 'NNP', 'B-NP'),
#  ("'s", 'POS', 'O'),
#  ('brief', 'NN', 'B-NP'),
#  ('ouster', 'NN', 'B-NP'),
#  ('.', '.', 'O')]

# %%
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
ne_tree = nltk.ne_chunk(pos_tag(word_tokenize(about_text)))
print(ne_tree)
# Out:
# (S
#   According/VBG
#   to/TO
#   the/DT
#   outlet/NN
#   ,/,
#   the/DT
#   (ORGANIZATION OpenAI/NNP)
#   CEO/NNP
#   recently/RB
#   reached/VBD
#   an/DT
#   agreement/NN
#   with/IN
#   the/DT
#   (ORGANIZATION iPhone/NN)
#   maker/NN
#   to/TO
#   incorporate/VB
#   some/DT
#   OpenAI/NNP
#   services/NNS
#   into/IN
#   (GPE Apple/NNP)
#   products/NNS
#   ./.
#   (PERSON Nadella/NN)
#   was/VBD
#   reportedly/RB
#   concerned/VBN
#   about/IN
#   the/DT
#   potential/JJ
#   impact/NN
#   of/IN
#   a/DT
#   deal/NN
#   on/IN
#   (ORGANIZATION Microsoft/NNP)
#   's/POS
#   product/NN
#   ambitions/NNS
#   ,/,
#   per/IN
#   the/DT
#   report/NN
#   ./.
#   Representatives/NNS
#   for/IN
#   (ORGANIZATION OpenAI/NNP)
#   ,/,
#   (PERSON Apple/NNP)
#   ,/,
#   and/CC
#   (PERSON Microsoft/NNP)
#   did/VBD
#   not/RB
#   immediately/RB
#   respond/VB
#   to/TO
#   requests/NNS
#   for/IN
#   comment/NN
#   from/IN
#   (ORGANIZATION Business/NNP Insider/NNP)
#   ,/,
#   made/VBD
#   outside/IN
#   normal/JJ
#   working/JJ
#   hours/NNS
#   ./.
#   (PERSON Apple/NNP)
#   and/CC
#   (ORGANIZATION OpenAI/NNP)
#   declined/VBD
#   to/TO
#   comment/VB
#   to/TO
#   The/DT
#   Information/NNP
#   ./.
#   If/IN
#   (ORGANIZATION OpenAI/NNP)
#   has/VBZ
#   indeed/RB
#   reached/VBN
#   an/DT
#   agreement/NN
#   with/IN
#   (PERSON Apple/NNP)
#   ,/,
#   it/PRP
#   would/MD
#   be/VB
#   a/DT
#   much-needed/JJ
#   win/NN
#   for/IN
#   (PERSON Altman/NNP)
#   ./.
#   The/DT
#   tech/NN
#   boss/NN
#   has/VBZ
#   faced/VBN
#   heightened/VBN
#   scrutiny/NN
#   after/IN
#   former/JJ
#   employees/NNS
#   and/CC
#   board/NN
#   members/NNS
#   publicly/RB
#   criticized/VBD
#   him/PRP
#   ./.
#   (PERSON Helen/NNP Toner/NNP)
#   ,/,
#   a/DT
#   former/JJ
#   (ORGANIZATION OpenAI/NNP)
#   director/NN
#   ,/,
#   recently/RB
#   accused/VBD
#   (PERSON Altman/NNP)
#   of/IN
#   lying/VBG
#   to/TO
#   the/DT
#   board/NN
#   ``/``
#   multiple/NN
#   ''/''
#   times/NNS
#   and/CC
#   ``/``
#   withholding/JJ
#   information/NN
#   ./.
#   (PERSON Toner/NNP)
#   ,/,
#   who/WP
#   participated/VBD
#   in/IN
#   (GPE November/NNP)
#   's/POS
#   ousting/NN
#   of/IN
#   the/DT
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   said/VBD
#   (PERSON Altman/NNP)
#   had/VBD
#   also/RB
#   kept/VBN
#   the/DT
#   board/NN
#   in/IN
#   the/DT
#   dark/NN
#   about/IN
#   the/DT
#   company/NN
#   's/POS
#   ownership/NN
#   structure/NN
#   ./.
#   (PERSON Altman/NNP)
#   has/VBZ
#   also/RB
#   faced/VBN
#   criticism/NN
#   from/IN
#   (PERSON Jan/NNP Lieke/NNP)
#   ,/,
#   a/DT
#   former/JJ
#   executive/NN
#   at/IN
#   (ORGANIZATION OpenAI/NNP)
#   ./.
#   (PERSON Leike/NNP)
#   quit/NN
#   (ORGANIZATION OpenAI/NNP)
#   earlier/RBR
#   this/DT
#   month/NN
#   ,/,
#   accusing/VBG
#   the/DT
#   company/NN
#   of/IN
#   prioritizing/VBG
#   ``/``
#   shiny/JJ
#   products/NNS
#   ''/''
#   over/IN
#   ``/``
#   safety/NN
#   culture/NN
#   and/CC
#   processes/NNS
#   ./.
#   ''/''
#   Tensions/NNPS
#   over/IN
#   the/DT
#   priorities/NNS
#   within/IN
#   (ORGANIZATION OpenAI/NNP)
#   had/VBD
#   reportedly/RB
#   been/VBN
#   brewing/VBG
#   since/IN
#   (PERSON Altman/NNP)
#   's/POS
#   brief/NN
#   ouster/NN
#   ./.)

# %%
#SENTIMENT ANALYSIS/Text Classification using Spacy

import spacy
from spacy.tokens import DocBin
from spacy.training import Example 
examples = []

# Prepare training data
train_data = [
    ("I love programming.", {"cats": {"POSITIVE": 1.0, "NEGATIVE": 0.0}}),
    ("I hate bugs.", {"cats": {"POSITIVE": 0.0, "NEGATIVE": 1.0}}),
]

# Create a blank model
nlp = spacy.blank("en")

# Add the text categorizer to the pipeline
textcat = nlp.add_pipe("textcat")

# Add labels to the text categorizer
textcat.add_label("POSITIVE")
textcat.add_label("NEGATIVE")

# Convert training data to DocBin
doc_bin = DocBin()
for text, annotations in train_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# Train the model (simplified)
nlp.initialize()
for epoch in range(10):
    nlp.update(examples)

# Test the model
doc = nlp("Learning new things is ok.")
print(doc.cats)
# Out:
# {'POSITIVE': 0.5251275300979614, 'NEGATIVE': 0.4748724699020386}

# %%
#Textbook Classification

import spacy
from spacy.tokens import DocBin
from spacy.training import Example 
examples = []

# Prepare training data
# train_data = [
#     ("I love programming.", {"cats": {"POSITIVE": 1.0, "NEGATIVE": 0.0}}),
#     ("Excitmement is the best feeling.", {"cats": {"POSITIVE": 1.0, "NEGATIVE": 0.0}}),
#     ("I hate bugs.", {"cats": {"POSITIVE": 0.0, "NEGATIVE": 1.0}}),
# ]
train_data = [
    
    ("On Language", {"cats": {"FICTION": 0.0, "NON-FICTION": 1.0}}),
    ("The Great Gatsby", {"cats": {"FICTION": 1.0, "NON-FICTION": 0.0}}),
    ("The Elements of Style", {"cats": {"FICTION": 0.0, "NON-FICTION": 1.0}}),
    ("The Catcher in the Rye", {"cats": {"FICTION": 1.0, "NON-FICTION": 0.0}}),
    ("The Design of Everyday Things", {"cats": {"FICTION": 0.0, "NON-FICTION": 1.0}}),
    ("The Old Man and the Sea", {"cats": {"FICTION": 1.0, "NON-FICTION": 0.0}}),
    ("The Art of Computer Programming", {"cats": {"FICTION": 0.0, "NON-FICTION": 1.0}})
]

# Create a blank model
nlp = spacy.blank("en")

# Add the text categorizer to the pipeline
textcat = nlp.add_pipe("textcat")

# Add labels to the text categorizer
textcat.add_label("FICTION")
textcat.add_label("NON-FICTION")

# Convert training data to DocBin
doc_bin = DocBin()
for text, annotations in train_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# Train the model (simplified)
nlp.initialize()
for epoch in range(10):
    nlp.update(examples)

# Test the model
doc = nlp("On the road")
print(doc.cats)
# Out:
# {'FICTION': 0.5461692214012146, 'NON-FICTION': 0.4538307785987854}

# %%
#SENTIMENT ANALYSIS/Text Classification using NLTK

import nltk
from nltk.tokenize import word_tokenize
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy as nltk_accuracy

# Prepare training data
train_data = [
    ("I love programming.", "POSITIVE"),
    ("I hate bugs.", "NEGATIVE"),
    ("It is not enjoyable to program.", "NEGATIVE"),
]

# Extract features
def extract_features(words):
    return {word: True for word in words}
train_features = [(extract_features(word_tokenize(text)), label) for text, label in train_data]


# Convert training data
train_features = [(extract_features(word_tokenize(text)), label) for text, label in train_data]

# Train the classifier
classifier = NaiveBayesClassifier.train(train_features)

# Test the classifier
test_sentence = "I enjoy working with a VCR."
test_features = extract_features(word_tokenize(test_sentence))
print(classifier.classify(test_features))
# Out:
# NEGATIVE
